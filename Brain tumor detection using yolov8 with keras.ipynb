# %%
# Importing dependencies

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
from tqdm.notebook import tqdm

import tensorflow as tf
from tensorflow.keras import *
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import Callback
import keras_cv


BATCH_SIZE = 4
GLOBAL_CLIPNORM = 10.0

AUTO = tf.data.AUTOTUNE
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Using TensorFlow backend

# %% [markdown]
# # <span style="color:#e74c3c;"> </span> Preprocessing

# %%
# a function for converting txt file to list
def parse_txt_annot(img_path, txt_path):
    img = cv2.imread(img_path)
    w = int(img.shape[0])
    h = int(img.shape[1])

    file_label = open(txt_path, "r")
    lines = file_label.read().split('\n')
    
    boxes = []
    classes = []
    
    if lines[0] == '':
        return img_path, classes, boxes
    else:
        for i in range(0, int(len(lines))):
            objbud=lines[i].split(' ')
            class_ = int(objbud[0])
        
            x1 = float(objbud[1])
            y1 = float(objbud[2])
            w1 = float(objbud[3])
            h1 = float(objbud[4])
        
            xmin = int((x1*w) - (w1*w)/2.0)
            ymin = int((y1*h) - (h1*h)/2.0)
            xmax = int((x1*w) + (w1*w)/2.0)
            ymax = int((y1*h) + (h1*h)/2.0)
    
            boxes.append([xmin ,ymin ,xmax ,ymax])
            classes.append(class_)
    
    return img_path, classes, boxes


# a function for creating file paths list 
def create_paths_list(path):
    full_path = []
    images = sorted(os.listdir(path))
    
    for i in images:
        full_path.append(os.path.join(path, i))
        
    return full_path


class_ids = ['label0', 'label1', 'label2']
class_mapping = dict(zip(range(len(class_ids)), class_ids))

class_mapping
# Out:
# {0: 'label0', 1: 'label1', 2: 'label2'}

# %%
# a function for creating a dict format of files
def creating_files(img_files_paths, annot_files_paths):
    
    img_files = create_paths_list(img_files_paths)
    annot_files = create_paths_list(annot_files_paths)
    
    image_paths = []
    bbox = []
    classes = []
    
    for i in range(0,len(img_files)):
        image_path_, classes_, bbox_ = parse_txt_annot(img_files[i], annot_files[i])
        image_paths.append(image_path_)
        bbox.append(bbox_)
        classes.append(classes_)
        
    image_paths = tf.ragged.constant(image_paths)
    bbox = tf.ragged.constant(bbox)
    classes = tf.ragged.constant(classes)
    
    return image_paths, classes, bbox

# %%
# applying functions
train_img_paths, train_classes, train_bboxes = creating_files('/kaggle/input/medical-image-dataset-brain-tumor-detection/BrainTumorYolov8/train/images', 
                                                              '/kaggle/input/medical-image-dataset-brain-tumor-detection/BrainTumorYolov8/train/labels')

valid_img_paths, valid_classes, valid_bboxes = creating_files('/kaggle/input/medical-image-dataset-brain-tumor-detection/BrainTumorYolov8/valid/images', 
                                                              '/kaggle/input/medical-image-dataset-brain-tumor-detection/BrainTumorYolov8/valid/labels')

test_img_paths, test_classes, test_bboxes = creating_files('/kaggle/input/medical-image-dataset-brain-tumor-detection/BrainTumorYolov8/test/images', 
                                                            '/kaggle/input/medical-image-dataset-brain-tumor-detection/BrainTumorYolov8/test/labels')

# %% [markdown]
# # <span style="color:#e74c3c;"> Creating </span> Datasets

# %%
# reading and resizing images
def img_preprocessing(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels = 3)
    img = tf.cast(img, tf.float32) 
    
    return img


resizing = keras_cv.layers.JitteredResize(
    target_size=(640, 640),
    scale_factor=(0.8, 1.25),
    bounding_box_format="xyxy")

# loading dataset
def load_ds(img_paths, classes, bbox):
    img = img_preprocessing(img_paths)

    bounding_boxes = {
        "classes": tf.cast(classes, dtype=tf.float32),
        "boxes": bbox }
    
    return {"images": img, "bounding_boxes": bounding_boxes}

def dict_to_tuple(inputs):
    return inputs["images"], inputs["bounding_boxes"]

# %%
# Creating dataset loaders and tf.datasets
train_loader = tf.data.Dataset.from_tensor_slices((train_img_paths, train_classes, train_bboxes))
train_dataset = (train_loader
                 .map(load_ds, num_parallel_calls = AUTO)
                 .shuffle(BATCH_SIZE*10)
                 .ragged_batch(BATCH_SIZE, drop_remainder = True)
                 .map(resizing, num_parallel_calls = AUTO)
                 .map(dict_to_tuple, num_parallel_calls = AUTO)
                 .prefetch(AUTO))


valid_loader = tf.data.Dataset.from_tensor_slices((valid_img_paths, valid_classes, valid_bboxes))
valid_dataset = (valid_loader
                 .map(load_ds, num_parallel_calls = AUTO)
                 .ragged_batch(BATCH_SIZE, drop_remainder = True)
                 .map(resizing, num_parallel_calls = AUTO)
                 .map(dict_to_tuple, num_parallel_calls = AUTO)
                 .prefetch(AUTO))


test_loader = tf.data.Dataset.from_tensor_slices((test_img_paths, test_classes, test_bboxes))
test_dataset = (test_loader
                .map(load_ds, num_parallel_calls = AUTO)
                .ragged_batch(BATCH_SIZE, drop_remainder = True)
                .map(resizing, num_parallel_calls = AUTO)
                .map(dict_to_tuple, num_parallel_calls = AUTO)
                .prefetch(AUTO))

# %%
# a function to visualize samples from a dataset

def visualize_dataset(inputs, value_range, rows, cols, bounding_box_format):
    inputs = next(iter(inputs.take(1)))
    images, bounding_boxes = inputs[0], inputs[1]
    
    keras_cv.visualization.plot_bounding_box_gallery(
        images,
        value_range=value_range,
        rows=rows,
        cols=cols,
        y_true=bounding_boxes,
        scale = 8,
        font_scale = 0.8,
        line_thickness=2,
        dpi = 100,
        bounding_box_format=bounding_box_format,
        class_mapping=class_mapping,
        true_color = (192, 57, 43))

# %%
# examples images and annotations from training daatset
visualize_dataset(train_dataset, bounding_box_format="xyxy", value_range=(0, 255), rows=2, cols=2)

# %% [markdown]
# # <span style="color:#e74c3c;"> YOLO V8</span> Model

# %%
# creating mirrored strategy

stg = tf.distribute.MirroredStrategy()

# %%
# creating pre-trained model backbone with coco weights

with stg.scope():
    backbone = keras_cv.models.YOLOV8Backbone.from_preset("yolo_v8_xs_backbone_coco")
    
    YOLOV8_model = keras_cv.models.YOLOV8Detector(num_classes=len(class_mapping),
                                              bounding_box_format="xyxy",
                                              backbone=backbone, fpn_depth=1 )

    optimizer = AdamW(learning_rate=0.0001, weight_decay=0.004, global_clipnorm = GLOBAL_CLIPNORM)

    YOLOV8_model.compile(optimizer = optimizer, classification_loss = 'binary_crossentropy', box_loss = 'ciou')
# Out:
# Attaching 'config.json' from model 'keras/yolov8/keras/yolo_v8_xs_backbone_coco/2' to your Kaggle notebook...
# Attaching 'config.json' from model 'keras/yolov8/keras/yolo_v8_xs_backbone_coco/2' to your Kaggle notebook...
# Attaching 'model.weights.h5' from model 'keras/yolov8/keras/yolo_v8_xs_backbone_coco/2' to your Kaggle notebook...
# /opt/conda/lib/python3.10/site-packages/keras_cv/src/models/backbones/backbone.py:44: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return id(getattr(self, attr)) not in self._functional_layer_ids
# /opt/conda/lib/python3.10/site-packages/keras_cv/src/models/backbones/backbone.py:44: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return id(getattr(self, attr)) not in self._functional_layer_ids

# %% [markdown]
# # <span style="color:#e74c3c;"> Training </span>

# %%
hist = YOLOV8_model.fit(train_dataset, validation_data = valid_dataset,  epochs = 120)
# Out:
# Epoch 1/120
# 536/536 [==============================] - 93s 90ms/step - loss: 338.2765 - box_loss: 2.1185 - class_loss: 336.1578 - val_loss: 188.5472 - val_box_loss: 2.0971 - val_class_loss: 186.4501
# Epoch 2/120
# 536/536 [==============================] - 47s 86ms/step - loss: 105.0890 - box_loss: 1.6725 - class_loss: 103.4165 - val_loss: 52.6271 - val_box_loss: 1.6980 - val_class_loss: 50.9291
# Epoch 3/120
# 536/536 [==============================] - 46s 85ms/step - loss: 29.2125 - box_loss: 1.5449 - class_loss: 27.6676 - val_loss: 17.5549 - val_box_loss: 2.2920 - val_class_loss: 15.2629
# Epoch 4/120
# 536/536 [==============================] - 46s 86ms/step - loss: 8.8329 - box_loss: 1.5367 - class_loss: 7.2962 - val_loss: 5.5107 - val_box_loss: 1.5405 - val_class_loss: 3.9702
# Epoch 5/120
# 536/536 [==============================] - 45s 84ms/step - loss: 4.3208 - box_loss: 1.5005 - class_loss: 2.8202 - val_loss: 3.8067 - val_box_loss: 1.5697 - val_class_loss: 2.2369
# Epoch 6/120
# 536/536 [==============================] - 46s 85ms/step - loss: 3.3608 - box_loss: 1.5369 - class_loss: 1.8239 - val_loss: 3.1394 - val_box_loss: 1.5352 - val_class_loss: 1.6042
# Epoch 7/120
# 536/536 [==============================] - 46s 86ms/step - loss: 3.0045 - box_loss: 1.5821 - class_loss: 1.4224 - val_loss: 2.9367 - val_box_loss: 1.5799 - val_class_loss: 1.3568
# Epoch 8/120
# 536/536 [==============================] - 47s 87ms/step - loss: 2.7821 - box_loss: 1.5821 - class_loss: 1.2000 - val_loss: 2.8514 - val_box_loss: 1.5908 - val_class_loss: 1.2605
# Epoch 9/120
# 536/536 [==============================] - 46s 85ms/step - loss: 2.6055 - box_loss: 1.5628 - class_loss: 1.0428 - val_loss: 2.6624 - val_box_loss: 1.5499 - val_class_loss: 1.1125
# Epoch 10/120
# 536/536 [==============================] - 45s 84ms/step - loss: 2.4550 - box_loss: 1.5109 - class_loss: 0.9440 - val_loss: 2.5613 - val_box_loss: 1.5453 - val_class_loss: 1.0160
# Epoch 11/120
# 536/536 [==============================] - 46s 85ms/step - loss: 2.3958 - box_loss: 1.5278 - class_loss: 0.8680 - val_loss: 2.5478 - val_box_loss: 1.5943 - val_class_loss: 0.9535
# Epoch 12/120
# 536/536 [==============================] - 45s 84ms/step - loss: 2.3022 - box_loss: 1.4984 - class_loss: 0.8038 - val_loss: 2.5548 - val_box_loss: 1.5733 - val_class_loss: 0.9814
# Epoch 13/120
# 536/536 [==============================] - 46s 85ms/step - loss: 2.2194 - box_loss: 1.4638 - class_loss: 0.7557 - val_loss: 2.4238 - val_box_loss: 1.5670 - val_class_loss: 0.8568
# Epoch 14/120
# 536/536 [==============================] - 45s 84ms/step - loss: 2.1710 - box_loss: 1.4520 - class_loss: 0.7190 - val_loss: 2.4097 - val_box_loss: 1.5503 - val_class_loss: 0.8593
# Epoch 15/120
# 536/536 [==============================] - 46s 85ms/step - loss: 2.1514 - box_loss: 1.4563 - class_loss: 0.6950 - val_loss: 2.4665 - val_box_loss: 1.5983 - val_class_loss: 0.8681
# Epoch 16/120
# 536/536 [==============================] - 45s 84ms/step - loss: 2.0709 - box_loss: 1.4063 - class_loss: 0.6647 - val_loss: 2.3281 - val_box_loss: 1.5541 - val_class_loss: 0.7740
# Epoch 17/120
# 536/536 [==============================] - 46s 84ms/step - loss: 2.0749 - box_loss: 1.4286 - class_loss: 0.6462 - val_loss: 2.3430 - val_box_loss: 1.5816 - val_class_loss: 0.7614
# Epoch 18/120
# 536/536 [==============================] - 46s 84ms/step - loss: 2.0445 - box_loss: 1.4119 - class_loss: 0.6326 - val_loss: 2.3503 - val_box_loss: 1.5920 - val_class_loss: 0.7584
# Epoch 19/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.9695 - box_loss: 1.3661 - class_loss: 0.6034 - val_loss: 2.3069 - val_box_loss: 1.5439 - val_class_loss: 0.7630
# Epoch 20/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.9576 - box_loss: 1.3643 - class_loss: 0.5933 - val_loss: 2.2999 - val_box_loss: 1.5726 - val_class_loss: 0.7272
# Epoch 21/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.9154 - box_loss: 1.3487 - class_loss: 0.5667 - val_loss: 2.3732 - val_box_loss: 1.6067 - val_class_loss: 0.7665
# Epoch 22/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.8791 - box_loss: 1.3241 - class_loss: 0.5550 - val_loss: 2.2531 - val_box_loss: 1.5484 - val_class_loss: 0.7046
# Epoch 23/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.8203 - box_loss: 1.2944 - class_loss: 0.5260 - val_loss: 2.2639 - val_box_loss: 1.5565 - val_class_loss: 0.7073
# Epoch 24/120
# 536/536 [==============================] - 45s 83ms/step - loss: 1.7948 - box_loss: 1.2879 - class_loss: 0.5069 - val_loss: 2.3276 - val_box_loss: 1.6352 - val_class_loss: 0.6924
# Epoch 25/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.7476 - box_loss: 1.2588 - class_loss: 0.4888 - val_loss: 2.3484 - val_box_loss: 1.6398 - val_class_loss: 0.7085
# Epoch 26/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.6995 - box_loss: 1.2275 - class_loss: 0.4720 - val_loss: 2.5304 - val_box_loss: 1.7614 - val_class_loss: 0.7690
# Epoch 27/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.6678 - box_loss: 1.2110 - class_loss: 0.4568 - val_loss: 2.4339 - val_box_loss: 1.6945 - val_class_loss: 0.7394
# Epoch 28/120
# 536/536 [==============================] - 46s 84ms/step - loss: 1.6135 - box_loss: 1.1760 - class_loss: 0.4375 - val_loss: 2.4510 - val_box_loss: 1.7203 - val_class_loss: 0.7306
# Epoch 29/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.5822 - box_loss: 1.1665 - class_loss: 0.4156 - val_loss: 2.4701 - val_box_loss: 1.7500 - val_class_loss: 0.7201
# Epoch 30/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.5582 - box_loss: 1.1565 - class_loss: 0.4017 - val_loss: 2.4978 - val_box_loss: 1.7894 - val_class_loss: 0.7084
# Epoch 31/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.5273 - box_loss: 1.1412 - class_loss: 0.3861 - val_loss: 2.4862 - val_box_loss: 1.7570 - val_class_loss: 0.7292
# Epoch 32/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.4765 - box_loss: 1.1048 - class_loss: 0.3717 - val_loss: 2.5040 - val_box_loss: 1.8059 - val_class_loss: 0.6980
# Epoch 33/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.4824 - box_loss: 1.1159 - class_loss: 0.3664 - val_loss: 2.5153 - val_box_loss: 1.7992 - val_class_loss: 0.7161
# Epoch 34/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.4282 - box_loss: 1.0744 - class_loss: 0.3539 - val_loss: 2.6079 - val_box_loss: 1.8572 - val_class_loss: 0.7508
# Epoch 35/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.4047 - box_loss: 1.0668 - class_loss: 0.3380 - val_loss: 2.5079 - val_box_loss: 1.7918 - val_class_loss: 0.7161
# Epoch 36/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.3708 - box_loss: 1.0461 - class_loss: 0.3248 - val_loss: 2.6129 - val_box_loss: 1.9046 - val_class_loss: 0.7082
# Epoch 37/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.3413 - box_loss: 1.0246 - class_loss: 0.3166 - val_loss: 2.5545 - val_box_loss: 1.8467 - val_class_loss: 0.7078
# Epoch 38/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.3382 - box_loss: 1.0314 - class_loss: 0.3068 - val_loss: 2.5999 - val_box_loss: 1.8561 - val_class_loss: 0.7438
# Epoch 39/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.2946 - box_loss: 1.0029 - class_loss: 0.2917 - val_loss: 2.5875 - val_box_loss: 1.8698 - val_class_loss: 0.7176
# Epoch 40/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.2799 - box_loss: 0.9942 - class_loss: 0.2857 - val_loss: 2.6862 - val_box_loss: 1.9144 - val_class_loss: 0.7718
# Epoch 41/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.2803 - box_loss: 0.9972 - class_loss: 0.2831 - val_loss: 2.6304 - val_box_loss: 1.8286 - val_class_loss: 0.8018
# Epoch 42/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.2376 - box_loss: 0.9648 - class_loss: 0.2728 - val_loss: 2.6903 - val_box_loss: 1.9231 - val_class_loss: 0.7672
# Epoch 43/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.2482 - box_loss: 0.9778 - class_loss: 0.2703 - val_loss: 2.6639 - val_box_loss: 1.9252 - val_class_loss: 0.7387
# Epoch 44/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.2049 - box_loss: 0.9477 - class_loss: 0.2572 - val_loss: 2.5919 - val_box_loss: 1.8909 - val_class_loss: 0.7011
# Epoch 45/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.1883 - box_loss: 0.9369 - class_loss: 0.2514 - val_loss: 2.6487 - val_box_loss: 1.9261 - val_class_loss: 0.7226
# Epoch 46/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.1966 - box_loss: 0.9454 - class_loss: 0.2512 - val_loss: 2.6939 - val_box_loss: 1.9525 - val_class_loss: 0.7414
# Epoch 47/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.1673 - box_loss: 0.9219 - class_loss: 0.2454 - val_loss: 2.7184 - val_box_loss: 1.9916 - val_class_loss: 0.7268
# Epoch 48/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.1697 - box_loss: 0.9317 - class_loss: 0.2380 - val_loss: 2.7362 - val_box_loss: 1.9394 - val_class_loss: 0.7968
# Epoch 49/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.1286 - box_loss: 0.8947 - class_loss: 0.2339 - val_loss: 2.6734 - val_box_loss: 1.9088 - val_class_loss: 0.7646
# Epoch 50/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.1213 - box_loss: 0.8944 - class_loss: 0.2269 - val_loss: 2.6586 - val_box_loss: 1.9271 - val_class_loss: 0.7316
# Epoch 51/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.1186 - box_loss: 0.8924 - class_loss: 0.2261 - val_loss: 2.7487 - val_box_loss: 1.9790 - val_class_loss: 0.7697
# Epoch 52/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.1201 - box_loss: 0.8983 - class_loss: 0.2217 - val_loss: 2.7777 - val_box_loss: 1.9445 - val_class_loss: 0.8332
# Epoch 53/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.0958 - box_loss: 0.8773 - class_loss: 0.2186 - val_loss: 2.7003 - val_box_loss: 1.9970 - val_class_loss: 0.7034
# Epoch 54/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.1092 - box_loss: 0.8873 - class_loss: 0.2219 - val_loss: 2.7049 - val_box_loss: 1.9847 - val_class_loss: 0.7202
# Epoch 55/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.0611 - box_loss: 0.8502 - class_loss: 0.2109 - val_loss: 2.6785 - val_box_loss: 1.9571 - val_class_loss: 0.7214
# Epoch 56/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.0827 - box_loss: 0.8679 - class_loss: 0.2148 - val_loss: 2.6843 - val_box_loss: 1.9902 - val_class_loss: 0.6940
# Epoch 57/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.0518 - box_loss: 0.8426 - class_loss: 0.2091 - val_loss: 2.8025 - val_box_loss: 1.9959 - val_class_loss: 0.8066
# Epoch 58/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.0479 - box_loss: 0.8441 - class_loss: 0.2039 - val_loss: 2.7276 - val_box_loss: 1.9499 - val_class_loss: 0.7778
# Epoch 59/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.0436 - box_loss: 0.8411 - class_loss: 0.2025 - val_loss: 2.7775 - val_box_loss: 2.0228 - val_class_loss: 0.7548
# Epoch 60/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.0518 - box_loss: 0.8457 - class_loss: 0.2062 - val_loss: 2.6778 - val_box_loss: 1.9159 - val_class_loss: 0.7619
# Epoch 61/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.0190 - box_loss: 0.8251 - class_loss: 0.1939 - val_loss: 2.7576 - val_box_loss: 2.0192 - val_class_loss: 0.7384
# Epoch 62/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.0258 - box_loss: 0.8303 - class_loss: 0.1955 - val_loss: 2.8418 - val_box_loss: 2.0030 - val_class_loss: 0.8388
# Epoch 63/120
# 536/536 [==============================] - 45s 84ms/step - loss: 1.0082 - box_loss: 0.8198 - class_loss: 0.1884 - val_loss: 2.7938 - val_box_loss: 2.0507 - val_class_loss: 0.7431
# Epoch 64/120
# 536/536 [==============================] - 46s 84ms/step - loss: 0.9924 - box_loss: 0.8069 - class_loss: 0.1855 - val_loss: 2.7859 - val_box_loss: 2.0391 - val_class_loss: 0.7469
# Epoch 65/120
# 536/536 [==============================] - 46s 84ms/step - loss: 0.9980 - box_loss: 0.8108 - class_loss: 0.1871 - val_loss: 2.8508 - val_box_loss: 2.0252 - val_class_loss: 0.8255
# Epoch 66/120
# 536/536 [==============================] - 45s 84ms/step - loss: 0.9726 - box_loss: 0.7895 - class_loss: 0.1831 - val_loss: 2.7790 - val_box_loss: 1.9663 - val_class_loss: 0.8126
# Epoch 67/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.9688 - box_loss: 0.7890 - class_loss: 0.1798 - val_loss: 2.7877 - val_box_loss: 2.0308 - val_class_loss: 0.7569
# Epoch 68/120
# 536/536 [==============================] - 45s 84ms/step - loss: 0.9838 - box_loss: 0.7917 - class_loss: 0.1921 - val_loss: 2.7316 - val_box_loss: 2.0087 - val_class_loss: 0.7229
# Epoch 69/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.9648 - box_loss: 0.7830 - class_loss: 0.1818 - val_loss: 2.7889 - val_box_loss: 2.0359 - val_class_loss: 0.7530
# Epoch 70/120
# 536/536 [==============================] - 45s 84ms/step - loss: 0.9563 - box_loss: 0.7739 - class_loss: 0.1825 - val_loss: 2.7562 - val_box_loss: 2.0005 - val_class_loss: 0.7557
# Epoch 71/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.9521 - box_loss: 0.7760 - class_loss: 0.1760 - val_loss: 2.8491 - val_box_loss: 2.0234 - val_class_loss: 0.8257
# Epoch 72/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.9405 - box_loss: 0.7682 - class_loss: 0.1723 - val_loss: 2.8594 - val_box_loss: 2.1252 - val_class_loss: 0.7342
# Epoch 73/120
# 536/536 [==============================] - 45s 84ms/step - loss: 0.9401 - box_loss: 0.7700 - class_loss: 0.1701 - val_loss: 2.9260 - val_box_loss: 2.0430 - val_class_loss: 0.8829
# Epoch 74/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.9409 - box_loss: 0.7681 - class_loss: 0.1728 - val_loss: 2.8358 - val_box_loss: 2.0606 - val_class_loss: 0.7752
# Epoch 75/120
# 536/536 [==============================] - 46s 84ms/step - loss: 0.9263 - box_loss: 0.7557 - class_loss: 0.1705 - val_loss: 2.8641 - val_box_loss: 2.0628 - val_class_loss: 0.8013
# Epoch 76/120
# 536/536 [==============================] - 45s 84ms/step - loss: 0.9213 - box_loss: 0.7552 - class_loss: 0.1661 - val_loss: 2.8645 - val_box_loss: 2.0027 - val_class_loss: 0.8617
# Epoch 77/120
# 536/536 [==============================] - 47s 86ms/step - loss: 0.9241 - box_loss: 0.7576 - class_loss: 0.1665 - val_loss: 2.9074 - val_box_loss: 2.1192 - val_class_loss: 0.7882
# Epoch 78/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.9241 - box_loss: 0.7534 - class_loss: 0.1707 - val_loss: 2.8312 - val_box_loss: 2.0031 - val_class_loss: 0.8281
# Epoch 79/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8918 - box_loss: 0.7294 - class_loss: 0.1624 - val_loss: 2.9077 - val_box_loss: 2.0327 - val_class_loss: 0.8749
# Epoch 80/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.9015 - box_loss: 0.7370 - class_loss: 0.1645 - val_loss: 2.8099 - val_box_loss: 1.9750 - val_class_loss: 0.8349
# Epoch 81/120
# 536/536 [==============================] - 46s 84ms/step - loss: 0.8858 - box_loss: 0.7270 - class_loss: 0.1588 - val_loss: 2.8871 - val_box_loss: 2.0725 - val_class_loss: 0.8147
# Epoch 82/120
# 536/536 [==============================] - 46s 84ms/step - loss: 0.9060 - box_loss: 0.7447 - class_loss: 0.1613 - val_loss: 2.9390 - val_box_loss: 2.0960 - val_class_loss: 0.8430
# Epoch 83/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8765 - box_loss: 0.7164 - class_loss: 0.1601 - val_loss: 2.8751 - val_box_loss: 1.9984 - val_class_loss: 0.8767
# Epoch 84/120
# 536/536 [==============================] - 46s 84ms/step - loss: 0.8674 - box_loss: 0.7126 - class_loss: 0.1548 - val_loss: 2.8263 - val_box_loss: 2.0616 - val_class_loss: 0.7647
# Epoch 85/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8781 - box_loss: 0.7233 - class_loss: 0.1548 - val_loss: 2.7925 - val_box_loss: 2.0277 - val_class_loss: 0.7647
# Epoch 86/120
# 536/536 [==============================] - 46s 84ms/step - loss: 0.8820 - box_loss: 0.7260 - class_loss: 0.1560 - val_loss: 2.9449 - val_box_loss: 2.0672 - val_class_loss: 0.8776
# Epoch 87/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.8623 - box_loss: 0.7106 - class_loss: 0.1517 - val_loss: 3.0377 - val_box_loss: 2.1375 - val_class_loss: 0.9001
# Epoch 88/120
# 536/536 [==============================] - 45s 84ms/step - loss: 0.8498 - box_loss: 0.6971 - class_loss: 0.1528 - val_loss: 2.8126 - val_box_loss: 2.0165 - val_class_loss: 0.7961
# Epoch 89/120
# 536/536 [==============================] - 46s 84ms/step - loss: 0.8533 - box_loss: 0.7002 - class_loss: 0.1531 - val_loss: 2.8051 - val_box_loss: 2.0552 - val_class_loss: 0.7499
# Epoch 90/120
# 536/536 [==============================] - 45s 84ms/step - loss: 0.8510 - box_loss: 0.6963 - class_loss: 0.1547 - val_loss: 2.8559 - val_box_loss: 1.9830 - val_class_loss: 0.8729
# Epoch 91/120
# 536/536 [==============================] - 46s 84ms/step - loss: 0.8459 - box_loss: 0.6971 - class_loss: 0.1488 - val_loss: 2.9012 - val_box_loss: 2.0665 - val_class_loss: 0.8347
# Epoch 92/120
# 536/536 [==============================] - 45s 84ms/step - loss: 0.8472 - box_loss: 0.6980 - class_loss: 0.1492 - val_loss: 2.9354 - val_box_loss: 2.0759 - val_class_loss: 0.8594
# Epoch 93/120
# 536/536 [==============================] - 46s 84ms/step - loss: 0.8397 - box_loss: 0.6908 - class_loss: 0.1490 - val_loss: 2.8757 - val_box_loss: 2.0502 - val_class_loss: 0.8256
# Epoch 94/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8331 - box_loss: 0.6888 - class_loss: 0.1444 - val_loss: 2.9293 - val_box_loss: 2.0411 - val_class_loss: 0.8881
# Epoch 95/120
# 536/536 [==============================] - 45s 84ms/step - loss: 0.8239 - box_loss: 0.6789 - class_loss: 0.1449 - val_loss: 2.8603 - val_box_loss: 2.0069 - val_class_loss: 0.8534
# Epoch 96/120
# 536/536 [==============================] - 45s 84ms/step - loss: 0.8272 - box_loss: 0.6797 - class_loss: 0.1476 - val_loss: 2.8820 - val_box_loss: 2.0889 - val_class_loss: 0.7931
# Epoch 97/120
# 536/536 [==============================] - 46s 84ms/step - loss: 0.8188 - box_loss: 0.6737 - class_loss: 0.1451 - val_loss: 3.0106 - val_box_loss: 2.1195 - val_class_loss: 0.8910
# Epoch 98/120
# 536/536 [==============================] - 45s 84ms/step - loss: 0.8031 - box_loss: 0.6617 - class_loss: 0.1413 - val_loss: 2.8998 - val_box_loss: 2.0502 - val_class_loss: 0.8496
# Epoch 99/120
# 536/536 [==============================] - 45s 84ms/step - loss: 0.8227 - box_loss: 0.6761 - class_loss: 0.1466 - val_loss: 2.9171 - val_box_loss: 2.0525 - val_class_loss: 0.8645
# Epoch 100/120
# 536/536 [==============================] - 45s 84ms/step - loss: 0.7949 - box_loss: 0.6550 - class_loss: 0.1398 - val_loss: 2.9731 - val_box_loss: 2.1470 - val_class_loss: 0.8260
# Epoch 101/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8144 - box_loss: 0.6719 - class_loss: 0.1425 - val_loss: 2.9294 - val_box_loss: 2.1220 - val_class_loss: 0.8073
# Epoch 102/120
# 536/536 [==============================] - 45s 84ms/step - loss: 0.7850 - box_loss: 0.6490 - class_loss: 0.1360 - val_loss: 2.9648 - val_box_loss: 2.0582 - val_class_loss: 0.9066
# Epoch 103/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7948 - box_loss: 0.6568 - class_loss: 0.1380 - val_loss: 2.9637 - val_box_loss: 2.1180 - val_class_loss: 0.8458
# Epoch 104/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7885 - box_loss: 0.6487 - class_loss: 0.1398 - val_loss: 2.9910 - val_box_loss: 2.1114 - val_class_loss: 0.8795
# Epoch 105/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7871 - box_loss: 0.6504 - class_loss: 0.1367 - val_loss: 2.9587 - val_box_loss: 2.1171 - val_class_loss: 0.8416
# Epoch 106/120
# 536/536 [==============================] - 46s 84ms/step - loss: 0.8057 - box_loss: 0.6590 - class_loss: 0.1466 - val_loss: 2.8779 - val_box_loss: 2.0886 - val_class_loss: 0.7893
# Epoch 107/120
# 536/536 [==============================] - 46s 84ms/step - loss: 0.7884 - box_loss: 0.6535 - class_loss: 0.1349 - val_loss: 2.9628 - val_box_loss: 2.0701 - val_class_loss: 0.8927
# Epoch 108/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7815 - box_loss: 0.6455 - class_loss: 0.1361 - val_loss: 2.9595 - val_box_loss: 2.0934 - val_class_loss: 0.8662
# Epoch 109/120
# 536/536 [==============================] - 45s 84ms/step - loss: 0.7932 - box_loss: 0.6555 - class_loss: 0.1377 - val_loss: 2.9901 - val_box_loss: 2.1001 - val_class_loss: 0.8900
# Epoch 110/120
# 536/536 [==============================] - 45s 84ms/step - loss: 0.7669 - box_loss: 0.6327 - class_loss: 0.1342 - val_loss: 3.0184 - val_box_loss: 2.0855 - val_class_loss: 0.9329
# Epoch 111/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7660 - box_loss: 0.6340 - class_loss: 0.1320 - val_loss: 3.0138 - val_box_loss: 2.1418 - val_class_loss: 0.8719
# Epoch 112/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7624 - box_loss: 0.6299 - class_loss: 0.1325 - val_loss: 3.0216 - val_box_loss: 2.1355 - val_class_loss: 0.8861
# Epoch 113/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7586 - box_loss: 0.6263 - class_loss: 0.1323 - val_loss: 3.1685 - val_box_loss: 2.1143 - val_class_loss: 1.0542
# Epoch 114/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7552 - box_loss: 0.6262 - class_loss: 0.1290 - val_loss: 2.9265 - val_box_loss: 2.0636 - val_class_loss: 0.8629
# Epoch 115/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.7504 - box_loss: 0.6209 - class_loss: 0.1296 - val_loss: 2.9901 - val_box_loss: 2.1012 - val_class_loss: 0.8890
# Epoch 116/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7625 - box_loss: 0.6282 - class_loss: 0.1343 - val_loss: 2.9560 - val_box_loss: 2.0575 - val_class_loss: 0.8986
# Epoch 117/120
# 536/536 [==============================] - 47s 87ms/step - loss: 0.7576 - box_loss: 0.6234 - class_loss: 0.1342 - val_loss: 2.9990 - val_box_loss: 2.1097 - val_class_loss: 0.8893
# Epoch 118/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7458 - box_loss: 0.6156 - class_loss: 0.1302 - val_loss: 2.9694 - val_box_loss: 2.1002 - val_class_loss: 0.8692
# Epoch 119/120
# 536/536 [==============================] - 46s 84ms/step - loss: 0.7448 - box_loss: 0.6163 - class_loss: 0.1285 - val_loss: 2.9733 - val_box_loss: 2.0942 - val_class_loss: 0.8792
# Epoch 120/120
# 536/536 [==============================] - 45s 84ms/step - loss: 0.7346 - box_loss: 0.6085 - class_loss: 0.1260 - val_loss: 3.0755 - val_box_loss: 2.1673 - val_class_loss: 0.9083

# %% [markdown]
# # <span style="color:#e74c3c;"> Training </span> Results, Evaluation

# %%
fig, axs = plt.subplots(1,3, figsize = (18,5), dpi = 130)

axs[0].grid(linestyle="dashdot")
axs[0].set_title("Loss")
axs[0].plot(hist.history['loss'][1:])
axs[0].plot(hist.history['val_loss'][1:])
axs[0].legend(["train", "validataion"])

axs[1].grid(linestyle="dashdot")
axs[1].set_title("Box Loss")
axs[1].plot(hist.history['box_loss'])
axs[1].plot(hist.history['val_box_loss'])
axs[1].legend(["train",  "validataion"])

axs[2].grid(linestyle="dashdot")
axs[2].set_title("Class Loss")
axs[2].plot(hist.history['class_loss'][1:])
axs[2].plot(hist.history['val_class_loss'][1:])
axs[2].legend(["train",  "validataion"])

# %% [markdown]
# # <span style="color:#e74c3c;"> Test </span> Predictions

# %%
def visualize_predict_detections(model, dataset, bounding_box_format):
    images, y_true = next(iter(dataset.take(1)))
        
    y_pred = model.predict(images)
    y_pred = keras_cv.bounding_box.to_ragged(y_pred)
    
    keras_cv.visualization.plot_bounding_box_gallery(
        images,
        value_range=(0, 255),
        bounding_box_format=bounding_box_format,
        y_true=y_true,
        y_pred=y_pred,
        true_color = (192, 57, 43),
        pred_color=(255, 235, 59),
        scale = 8,
        font_scale = 0.8,
        line_thickness=2,
        dpi = 100,
        rows=2,
        cols=2,
        show=True,
        class_mapping=class_mapping,
    )
