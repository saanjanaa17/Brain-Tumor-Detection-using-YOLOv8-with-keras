# %%
# Importing dependencies

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
from tqdm.notebook import tqdm

import tensorflow as tf
from tensorflow.keras import *
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import Callback
import keras_cv


BATCH_SIZE = 4
GLOBAL_CLIPNORM = 10.0

AUTO = tf.data.AUTOTUNE
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Using TensorFlow backend

# %% [markdown]
# # <span style="color:#e74c3c;"> </span> Preprocessing

# %%
# a function for converting txt file to list
def parse_txt_annot(img_path, txt_path):
    img = cv2.imread(img_path)
    w = int(img.shape[0])
    h = int(img.shape[1])

    file_label = open(txt_path, "r")
    lines = file_label.read().split('\n')
    
    boxes = []
    classes = []
    
    if lines[0] == '':
        return img_path, classes, boxes
    else:
        for i in range(0, int(len(lines))):
            objbud=lines[i].split(' ')
            class_ = int(objbud[0])
        
            x1 = float(objbud[1])
            y1 = float(objbud[2])
            w1 = float(objbud[3])
            h1 = float(objbud[4])
        
            xmin = int((x1*w) - (w1*w)/2.0)
            ymin = int((y1*h) - (h1*h)/2.0)
            xmax = int((x1*w) + (w1*w)/2.0)
            ymax = int((y1*h) + (h1*h)/2.0)
    
            boxes.append([xmin ,ymin ,xmax ,ymax])
            classes.append(class_)
    
    return img_path, classes, boxes


# a function for creating file paths list 
def create_paths_list(path):
    full_path = []
    images = sorted(os.listdir(path))
    
    for i in images:
        full_path.append(os.path.join(path, i))
        
    return full_path


class_ids = ['label0', 'label1', 'label2']
class_mapping = dict(zip(range(len(class_ids)), class_ids))

class_mapping
# Out:
# {0: 'label0', 1: 'label1', 2: 'label2'}

# %%
# a function for creating a dict format of files
def creating_files(img_files_paths, annot_files_paths):
    
    img_files = create_paths_list(img_files_paths)
    annot_files = create_paths_list(annot_files_paths)
    
    image_paths = []
    bbox = []
    classes = []
    
    for i in range(0,len(img_files)):
        image_path_, classes_, bbox_ = parse_txt_annot(img_files[i], annot_files[i])
        image_paths.append(image_path_)
        bbox.append(bbox_)
        classes.append(classes_)
        
    image_paths = tf.ragged.constant(image_paths)
    bbox = tf.ragged.constant(bbox)
    classes = tf.ragged.constant(classes)
    
    return image_paths, classes, bbox

# %%
# applying functions
train_img_paths, train_classes, train_bboxes = creating_files('/kaggle/input/medical-image-dataset-brain-tumor-detection/BrainTumorYolov8/train/images', 
                                                              '/kaggle/input/medical-image-dataset-brain-tumor-detection/BrainTumorYolov8/train/labels')

valid_img_paths, valid_classes, valid_bboxes = creating_files('/kaggle/input/medical-image-dataset-brain-tumor-detection/BrainTumorYolov8/valid/images', 
                                                              '/kaggle/input/medical-image-dataset-brain-tumor-detection/BrainTumorYolov8/valid/labels')

test_img_paths, test_classes, test_bboxes = creating_files('/kaggle/input/medical-image-dataset-brain-tumor-detection/BrainTumorYolov8/test/images', 
                                                            '/kaggle/input/medical-image-dataset-brain-tumor-detection/BrainTumorYolov8/test/labels')

# %% [markdown]
# # <span style="color:#e74c3c;"> Creating </span> Datasets

# %%
# reading and resizing images
def img_preprocessing(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels = 3)
    img = tf.cast(img, tf.float32) 
    
    return img


resizing = keras_cv.layers.JitteredResize(
    target_size=(640, 640),
    scale_factor=(0.8, 1.25),
    bounding_box_format="xyxy")

# loading dataset
def load_ds(img_paths, classes, bbox):
    img = img_preprocessing(img_paths)

    bounding_boxes = {
        "classes": tf.cast(classes, dtype=tf.float32),
        "boxes": bbox }
    
    return {"images": img, "bounding_boxes": bounding_boxes}

def dict_to_tuple(inputs):
    return inputs["images"], inputs["bounding_boxes"]

# %%
# Creating dataset loaders and tf.datasets
train_loader = tf.data.Dataset.from_tensor_slices((train_img_paths, train_classes, train_bboxes))
train_dataset = (train_loader
                 .map(load_ds, num_parallel_calls = AUTO)
                 .shuffle(BATCH_SIZE*10)
                 .ragged_batch(BATCH_SIZE, drop_remainder = True)
                 .map(resizing, num_parallel_calls = AUTO)
                 .map(dict_to_tuple, num_parallel_calls = AUTO)
                 .prefetch(AUTO))


valid_loader = tf.data.Dataset.from_tensor_slices((valid_img_paths, valid_classes, valid_bboxes))
valid_dataset = (valid_loader
                 .map(load_ds, num_parallel_calls = AUTO)
                 .ragged_batch(BATCH_SIZE, drop_remainder = True)
                 .map(resizing, num_parallel_calls = AUTO)
                 .map(dict_to_tuple, num_parallel_calls = AUTO)
                 .prefetch(AUTO))


test_loader = tf.data.Dataset.from_tensor_slices((test_img_paths, test_classes, test_bboxes))
test_dataset = (test_loader
                .map(load_ds, num_parallel_calls = AUTO)
                .ragged_batch(BATCH_SIZE, drop_remainder = True)
                .map(resizing, num_parallel_calls = AUTO)
                .map(dict_to_tuple, num_parallel_calls = AUTO)
                .prefetch(AUTO))

# %%
# a function to visualize samples from a dataset

def visualize_dataset(inputs, value_range, rows, cols, bounding_box_format):
    inputs = next(iter(inputs.take(1)))
    images, bounding_boxes = inputs[0], inputs[1]
    
    keras_cv.visualization.plot_bounding_box_gallery(
        images,
        value_range=value_range,
        rows=rows,
        cols=cols,
        y_true=bounding_boxes,
        scale = 8,
        font_scale = 0.8,
        line_thickness=2,
        dpi = 100,
        bounding_box_format=bounding_box_format,
        class_mapping=class_mapping,
        true_color = (192, 57, 43))

# %%
# examples images and annotations from training daatset
visualize_dataset(train_dataset, bounding_box_format="xyxy", value_range=(0, 255), rows=2, cols=2)

# %% [markdown]
# # <span style="color:#e74c3c;"> YOLO V8</span> Model

# %%
# creating mirrored strategy

stg = tf.distribute.MirroredStrategy()

# %%
# creating pre-trained model backbone with coco weights

with stg.scope():
    backbone = keras_cv.models.YOLOV8Backbone.from_preset("yolo_v8_xs_backbone_coco")
    
    YOLOV8_model = keras_cv.models.YOLOV8Detector(num_classes=len(class_mapping),
                                              bounding_box_format="xyxy",
                                              backbone=backbone, fpn_depth=1 )

    optimizer = AdamW(learning_rate=0.0001, weight_decay=0.004, global_clipnorm = GLOBAL_CLIPNORM)

    YOLOV8_model.compile(optimizer = optimizer, classification_loss = 'binary_crossentropy', box_loss = 'ciou')
# Out:
# Attaching 'config.json' from model 'keras/yolov8/keras/yolo_v8_xs_backbone_coco/2' to your Kaggle notebook...
# Attaching 'config.json' from model 'keras/yolov8/keras/yolo_v8_xs_backbone_coco/2' to your Kaggle notebook...
# Attaching 'model.weights.h5' from model 'keras/yolov8/keras/yolo_v8_xs_backbone_coco/2' to your Kaggle notebook...
# /opt/conda/lib/python3.10/site-packages/keras_cv/src/models/backbones/backbone.py:44: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return id(getattr(self, attr)) not in self._functional_layer_ids
# /opt/conda/lib/python3.10/site-packages/keras_cv/src/models/backbones/backbone.py:44: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return id(getattr(self, attr)) not in self._functional_layer_ids

# %% [markdown]
# # <span style="color:#e74c3c;"> Training </span>

# %%
hist = YOLOV8_model.fit(train_dataset, validation_data = valid_dataset,  epochs = 120)
# Out:
# Epoch 1/120
# 536/536 [==============================] - 47s 87ms/step - loss: 2.3228 - box_loss: 1.4516 - class_loss: 0.8713 - val_loss: 2.5367 - val_box_loss: 1.5277 - val_class_loss: 1.0090
# Epoch 2/120
# 536/536 [==============================] - 46s 85ms/step - loss: 2.2609 - box_loss: 1.4666 - class_loss: 0.7943 - val_loss: 2.4387 - val_box_loss: 1.5512 - val_class_loss: 0.8875
# Epoch 3/120
# 536/536 [==============================] - 46s 85ms/step - loss: 2.1822 - box_loss: 1.4279 - class_loss: 0.7543 - val_loss: 2.4289 - val_box_loss: 1.5706 - val_class_loss: 0.8582
# Epoch 4/120
# 536/536 [==============================] - 47s 87ms/step - loss: 2.1278 - box_loss: 1.4109 - class_loss: 0.7169 - val_loss: 2.4179 - val_box_loss: 1.5937 - val_class_loss: 0.8242
# Epoch 5/120
# 536/536 [==============================] - 46s 86ms/step - loss: 2.0814 - box_loss: 1.4037 - class_loss: 0.6776 - val_loss: 2.4656 - val_box_loss: 1.5114 - val_class_loss: 0.9542
# Epoch 6/120
# 536/536 [==============================] - 46s 85ms/step - loss: 2.0403 - box_loss: 1.3908 - class_loss: 0.6495 - val_loss: 2.3628 - val_box_loss: 1.5836 - val_class_loss: 0.7792
# Epoch 7/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.9709 - box_loss: 1.3552 - class_loss: 0.6157 - val_loss: 2.3366 - val_box_loss: 1.5743 - val_class_loss: 0.7624
# Epoch 8/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.9357 - box_loss: 1.3413 - class_loss: 0.5945 - val_loss: 2.3998 - val_box_loss: 1.6061 - val_class_loss: 0.7937
# Epoch 9/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.8891 - box_loss: 1.3162 - class_loss: 0.5729 - val_loss: 2.3954 - val_box_loss: 1.6059 - val_class_loss: 0.7895
# Epoch 10/120
# 536/536 [==============================] - 47s 87ms/step - loss: 1.8652 - box_loss: 1.3129 - class_loss: 0.5524 - val_loss: 2.3498 - val_box_loss: 1.6119 - val_class_loss: 0.7378
# Epoch 11/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.8008 - box_loss: 1.2764 - class_loss: 0.5244 - val_loss: 2.4299 - val_box_loss: 1.6793 - val_class_loss: 0.7507
# Epoch 12/120
# 536/536 [==============================] - 47s 86ms/step - loss: 1.7297 - box_loss: 1.2337 - class_loss: 0.4960 - val_loss: 2.4270 - val_box_loss: 1.6933 - val_class_loss: 0.7338
# Epoch 13/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.7336 - box_loss: 1.2509 - class_loss: 0.4827 - val_loss: 2.4481 - val_box_loss: 1.7129 - val_class_loss: 0.7352
# Epoch 14/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.6858 - box_loss: 1.2160 - class_loss: 0.4698 - val_loss: 2.4429 - val_box_loss: 1.6903 - val_class_loss: 0.7526
# Epoch 15/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.6473 - box_loss: 1.1914 - class_loss: 0.4558 - val_loss: 2.4742 - val_box_loss: 1.7276 - val_class_loss: 0.7466
# Epoch 16/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.5971 - box_loss: 1.1665 - class_loss: 0.4306 - val_loss: 2.5150 - val_box_loss: 1.7748 - val_class_loss: 0.7402
# Epoch 17/120
# 536/536 [==============================] - 47s 86ms/step - loss: 1.5922 - box_loss: 1.1704 - class_loss: 0.4218 - val_loss: 2.5519 - val_box_loss: 1.8185 - val_class_loss: 0.7334
# Epoch 18/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.5128 - box_loss: 1.1123 - class_loss: 0.4005 - val_loss: 2.6361 - val_box_loss: 1.8832 - val_class_loss: 0.7529
# Epoch 19/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.4941 - box_loss: 1.1137 - class_loss: 0.3803 - val_loss: 2.5337 - val_box_loss: 1.7991 - val_class_loss: 0.7346
# Epoch 20/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.4510 - box_loss: 1.0792 - class_loss: 0.3718 - val_loss: 2.6098 - val_box_loss: 1.8557 - val_class_loss: 0.7540
# Epoch 21/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.4372 - box_loss: 1.0746 - class_loss: 0.3627 - val_loss: 2.6182 - val_box_loss: 1.8505 - val_class_loss: 0.7677
# Epoch 22/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.3999 - box_loss: 1.0539 - class_loss: 0.3460 - val_loss: 2.5639 - val_box_loss: 1.8275 - val_class_loss: 0.7364
# Epoch 23/120
# 536/536 [==============================] - 47s 87ms/step - loss: 1.3552 - box_loss: 1.0255 - class_loss: 0.3297 - val_loss: 2.6565 - val_box_loss: 1.9304 - val_class_loss: 0.7261
# Epoch 24/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.3641 - box_loss: 1.0458 - class_loss: 0.3183 - val_loss: 2.6148 - val_box_loss: 1.8216 - val_class_loss: 0.7932
# Epoch 25/120
# 536/536 [==============================] - 47s 86ms/step - loss: 1.3332 - box_loss: 1.0273 - class_loss: 0.3059 - val_loss: 2.5767 - val_box_loss: 1.8534 - val_class_loss: 0.7233
# Epoch 26/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.3136 - box_loss: 1.0062 - class_loss: 0.3074 - val_loss: 2.7006 - val_box_loss: 1.9395 - val_class_loss: 0.7611
# Epoch 27/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.3009 - box_loss: 0.9972 - class_loss: 0.3037 - val_loss: 2.6121 - val_box_loss: 1.8265 - val_class_loss: 0.7857
# Epoch 28/120
# 536/536 [==============================] - 47s 87ms/step - loss: 1.2513 - box_loss: 0.9679 - class_loss: 0.2834 - val_loss: 2.5726 - val_box_loss: 1.8499 - val_class_loss: 0.7227
# Epoch 29/120
# 536/536 [==============================] - 47s 87ms/step - loss: 1.2605 - box_loss: 0.9846 - class_loss: 0.2759 - val_loss: 2.7290 - val_box_loss: 1.9571 - val_class_loss: 0.7719
# Epoch 30/120
# 536/536 [==============================] - 47s 87ms/step - loss: 1.2347 - box_loss: 0.9610 - class_loss: 0.2737 - val_loss: 2.6535 - val_box_loss: 1.9128 - val_class_loss: 0.7406
# Epoch 31/120
# 536/536 [==============================] - 47s 86ms/step - loss: 1.2071 - box_loss: 0.9453 - class_loss: 0.2617 - val_loss: 2.7275 - val_box_loss: 1.9598 - val_class_loss: 0.7678
# Epoch 32/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.2190 - box_loss: 0.9516 - class_loss: 0.2674 - val_loss: 2.7467 - val_box_loss: 1.9224 - val_class_loss: 0.8243
# Epoch 33/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.1937 - box_loss: 0.9393 - class_loss: 0.2544 - val_loss: 2.6949 - val_box_loss: 1.9631 - val_class_loss: 0.7318
# Epoch 34/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.1823 - box_loss: 0.9313 - class_loss: 0.2511 - val_loss: 2.7082 - val_box_loss: 1.9579 - val_class_loss: 0.7503
# Epoch 35/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.1581 - box_loss: 0.9156 - class_loss: 0.2424 - val_loss: 2.7640 - val_box_loss: 1.9829 - val_class_loss: 0.7811
# Epoch 36/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.1424 - box_loss: 0.9009 - class_loss: 0.2414 - val_loss: 2.7064 - val_box_loss: 1.9508 - val_class_loss: 0.7557
# Epoch 37/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.1139 - box_loss: 0.8801 - class_loss: 0.2338 - val_loss: 2.7993 - val_box_loss: 2.0038 - val_class_loss: 0.7955
# Epoch 38/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.1157 - box_loss: 0.8834 - class_loss: 0.2323 - val_loss: 2.7085 - val_box_loss: 1.9344 - val_class_loss: 0.7741
# Epoch 39/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.1286 - box_loss: 0.8970 - class_loss: 0.2316 - val_loss: 2.7633 - val_box_loss: 2.0124 - val_class_loss: 0.7509
# Epoch 40/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.0996 - box_loss: 0.8778 - class_loss: 0.2218 - val_loss: 2.7118 - val_box_loss: 1.9574 - val_class_loss: 0.7544
# Epoch 41/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.0852 - box_loss: 0.8673 - class_loss: 0.2179 - val_loss: 2.8260 - val_box_loss: 1.9811 - val_class_loss: 0.8450
# Epoch 42/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.0867 - box_loss: 0.8691 - class_loss: 0.2176 - val_loss: 2.8004 - val_box_loss: 1.9937 - val_class_loss: 0.8067
# Epoch 43/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.0675 - box_loss: 0.8598 - class_loss: 0.2077 - val_loss: 2.8226 - val_box_loss: 1.9868 - val_class_loss: 0.8358
# Epoch 44/120
# 536/536 [==============================] - 50s 94ms/step - loss: 1.0496 - box_loss: 0.8447 - class_loss: 0.2050 - val_loss: 2.8750 - val_box_loss: 2.0220 - val_class_loss: 0.8530
# Epoch 45/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.0526 - box_loss: 0.8396 - class_loss: 0.2130 - val_loss: 2.8364 - val_box_loss: 1.9570 - val_class_loss: 0.8793
# Epoch 46/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.0433 - box_loss: 0.8410 - class_loss: 0.2023 - val_loss: 2.8315 - val_box_loss: 1.9963 - val_class_loss: 0.8352
# Epoch 47/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.0301 - box_loss: 0.8317 - class_loss: 0.1983 - val_loss: 2.7890 - val_box_loss: 2.0092 - val_class_loss: 0.7797
# Epoch 48/120
# 536/536 [==============================] - 46s 86ms/step - loss: 1.0016 - box_loss: 0.8056 - class_loss: 0.1960 - val_loss: 2.7803 - val_box_loss: 1.9944 - val_class_loss: 0.7860
# Epoch 49/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.0000 - box_loss: 0.8040 - class_loss: 0.1960 - val_loss: 2.7836 - val_box_loss: 1.9911 - val_class_loss: 0.7924
# Epoch 50/120
# 536/536 [==============================] - 46s 85ms/step - loss: 1.0022 - box_loss: 0.8101 - class_loss: 0.1921 - val_loss: 2.8252 - val_box_loss: 2.0439 - val_class_loss: 0.7813
# Epoch 51/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.9926 - box_loss: 0.8048 - class_loss: 0.1878 - val_loss: 2.7522 - val_box_loss: 1.9247 - val_class_loss: 0.8276
# Epoch 52/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.9943 - box_loss: 0.8000 - class_loss: 0.1943 - val_loss: 2.7607 - val_box_loss: 1.9959 - val_class_loss: 0.7648
# Epoch 53/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.9771 - box_loss: 0.7875 - class_loss: 0.1896 - val_loss: 2.8468 - val_box_loss: 2.0245 - val_class_loss: 0.8223
# Epoch 54/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.9747 - box_loss: 0.7908 - class_loss: 0.1839 - val_loss: 2.7371 - val_box_loss: 1.9654 - val_class_loss: 0.7717
# Epoch 55/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.9724 - box_loss: 0.7861 - class_loss: 0.1863 - val_loss: 2.7584 - val_box_loss: 1.9402 - val_class_loss: 0.8182
# Epoch 56/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.9704 - box_loss: 0.7894 - class_loss: 0.1810 - val_loss: 2.7538 - val_box_loss: 1.9781 - val_class_loss: 0.7757
# Epoch 57/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.9532 - box_loss: 0.7708 - class_loss: 0.1824 - val_loss: 2.8410 - val_box_loss: 2.0209 - val_class_loss: 0.8201
# Epoch 58/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.9277 - box_loss: 0.7546 - class_loss: 0.1730 - val_loss: 2.8535 - val_box_loss: 2.0740 - val_class_loss: 0.7795
# Epoch 59/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.9414 - box_loss: 0.7653 - class_loss: 0.1761 - val_loss: 2.8744 - val_box_loss: 2.0069 - val_class_loss: 0.8675
# Epoch 60/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.9330 - box_loss: 0.7600 - class_loss: 0.1731 - val_loss: 2.8124 - val_box_loss: 2.0377 - val_class_loss: 0.7747
# Epoch 61/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.9236 - box_loss: 0.7520 - class_loss: 0.1716 - val_loss: 2.7746 - val_box_loss: 1.9904 - val_class_loss: 0.7841
# Epoch 62/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.9136 - box_loss: 0.7460 - class_loss: 0.1676 - val_loss: 2.8098 - val_box_loss: 2.0016 - val_class_loss: 0.8082
# Epoch 63/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.9080 - box_loss: 0.7435 - class_loss: 0.1645 - val_loss: 2.9857 - val_box_loss: 2.0521 - val_class_loss: 0.9336
# Epoch 64/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.9190 - box_loss: 0.7524 - class_loss: 0.1666 - val_loss: 2.8778 - val_box_loss: 2.0652 - val_class_loss: 0.8126
# Epoch 65/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8948 - box_loss: 0.7310 - class_loss: 0.1638 - val_loss: 2.8797 - val_box_loss: 2.0315 - val_class_loss: 0.8482
# Epoch 66/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8720 - box_loss: 0.7134 - class_loss: 0.1586 - val_loss: 2.7652 - val_box_loss: 1.9585 - val_class_loss: 0.8067
# Epoch 67/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8732 - box_loss: 0.7164 - class_loss: 0.1568 - val_loss: 2.9039 - val_box_loss: 2.0169 - val_class_loss: 0.8871
# Epoch 68/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.9052 - box_loss: 0.7411 - class_loss: 0.1641 - val_loss: 2.9288 - val_box_loss: 2.0778 - val_class_loss: 0.8509
# Epoch 69/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8951 - box_loss: 0.7340 - class_loss: 0.1611 - val_loss: 2.8362 - val_box_loss: 2.0249 - val_class_loss: 0.8113
# Epoch 70/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8786 - box_loss: 0.7186 - class_loss: 0.1600 - val_loss: 2.8346 - val_box_loss: 2.0230 - val_class_loss: 0.8116
# Epoch 71/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.8785 - box_loss: 0.7183 - class_loss: 0.1602 - val_loss: 2.8365 - val_box_loss: 1.9956 - val_class_loss: 0.8409
# Epoch 72/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.8540 - box_loss: 0.6999 - class_loss: 0.1541 - val_loss: 2.9031 - val_box_loss: 2.0538 - val_class_loss: 0.8494
# Epoch 73/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.8548 - box_loss: 0.7003 - class_loss: 0.1545 - val_loss: 2.9324 - val_box_loss: 2.0602 - val_class_loss: 0.8722
# Epoch 74/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8489 - box_loss: 0.6943 - class_loss: 0.1546 - val_loss: 2.8740 - val_box_loss: 2.0152 - val_class_loss: 0.8589
# Epoch 75/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8484 - box_loss: 0.6991 - class_loss: 0.1493 - val_loss: 2.8303 - val_box_loss: 2.0314 - val_class_loss: 0.7989
# Epoch 76/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8482 - box_loss: 0.6967 - class_loss: 0.1515 - val_loss: 2.9236 - val_box_loss: 2.0621 - val_class_loss: 0.8615
# Epoch 77/120
# 536/536 [==============================] - 46s 84ms/step - loss: 0.8531 - box_loss: 0.6990 - class_loss: 0.1541 - val_loss: 2.7927 - val_box_loss: 1.9430 - val_class_loss: 0.8497
# Epoch 78/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8370 - box_loss: 0.6905 - class_loss: 0.1465 - val_loss: 2.8913 - val_box_loss: 2.0401 - val_class_loss: 0.8511
# Epoch 79/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8221 - box_loss: 0.6766 - class_loss: 0.1455 - val_loss: 2.8800 - val_box_loss: 2.0289 - val_class_loss: 0.8511
# Epoch 80/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8112 - box_loss: 0.6678 - class_loss: 0.1434 - val_loss: 2.9397 - val_box_loss: 2.0436 - val_class_loss: 0.8961
# Epoch 81/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8199 - box_loss: 0.6738 - class_loss: 0.1461 - val_loss: 2.9170 - val_box_loss: 2.0743 - val_class_loss: 0.8427
# Epoch 82/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8126 - box_loss: 0.6712 - class_loss: 0.1414 - val_loss: 2.8776 - val_box_loss: 2.0071 - val_class_loss: 0.8705
# Epoch 83/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8190 - box_loss: 0.6769 - class_loss: 0.1421 - val_loss: 2.8714 - val_box_loss: 2.0394 - val_class_loss: 0.8320
# Epoch 84/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8202 - box_loss: 0.6772 - class_loss: 0.1430 - val_loss: 2.8983 - val_box_loss: 2.0709 - val_class_loss: 0.8274
# Epoch 85/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7958 - box_loss: 0.6562 - class_loss: 0.1396 - val_loss: 2.9489 - val_box_loss: 2.1024 - val_class_loss: 0.8465
# Epoch 86/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8043 - box_loss: 0.6643 - class_loss: 0.1399 - val_loss: 2.9595 - val_box_loss: 2.0329 - val_class_loss: 0.9266
# Epoch 87/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.8009 - box_loss: 0.6572 - class_loss: 0.1438 - val_loss: 2.8856 - val_box_loss: 2.0383 - val_class_loss: 0.8473
# Epoch 88/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7811 - box_loss: 0.6431 - class_loss: 0.1379 - val_loss: 2.8459 - val_box_loss: 2.0081 - val_class_loss: 0.8378
# Epoch 89/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.7901 - box_loss: 0.6530 - class_loss: 0.1371 - val_loss: 2.9241 - val_box_loss: 2.0921 - val_class_loss: 0.8320
# Epoch 90/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7904 - box_loss: 0.6560 - class_loss: 0.1344 - val_loss: 2.9272 - val_box_loss: 1.9859 - val_class_loss: 0.9412
# Epoch 91/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7956 - box_loss: 0.6552 - class_loss: 0.1404 - val_loss: 2.9389 - val_box_loss: 2.0584 - val_class_loss: 0.8805
# Epoch 92/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.7762 - box_loss: 0.6395 - class_loss: 0.1367 - val_loss: 2.9037 - val_box_loss: 2.0597 - val_class_loss: 0.8441
# Epoch 93/120
# 536/536 [==============================] - 56s 104ms/step - loss: 0.7964 - box_loss: 0.6618 - class_loss: 0.1347 - val_loss: 2.9769 - val_box_loss: 2.0867 - val_class_loss: 0.8903
# Epoch 94/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7753 - box_loss: 0.6378 - class_loss: 0.1374 - val_loss: 2.9165 - val_box_loss: 2.0641 - val_class_loss: 0.8524
# Epoch 95/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.7767 - box_loss: 0.6419 - class_loss: 0.1348 - val_loss: 2.8177 - val_box_loss: 2.0222 - val_class_loss: 0.7956
# Epoch 96/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7659 - box_loss: 0.6320 - class_loss: 0.1339 - val_loss: 2.9161 - val_box_loss: 2.0790 - val_class_loss: 0.8372
# Epoch 97/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.7786 - box_loss: 0.6408 - class_loss: 0.1377 - val_loss: 2.9070 - val_box_loss: 2.0854 - val_class_loss: 0.8216
# Epoch 98/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7631 - box_loss: 0.6325 - class_loss: 0.1306 - val_loss: 2.9767 - val_box_loss: 2.0517 - val_class_loss: 0.9250
# Epoch 99/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7599 - box_loss: 0.6278 - class_loss: 0.1321 - val_loss: 2.9342 - val_box_loss: 1.9866 - val_class_loss: 0.9475
# Epoch 100/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7565 - box_loss: 0.6262 - class_loss: 0.1303 - val_loss: 2.9539 - val_box_loss: 2.1044 - val_class_loss: 0.8496
# Epoch 101/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7383 - box_loss: 0.6084 - class_loss: 0.1299 - val_loss: 2.9226 - val_box_loss: 2.0334 - val_class_loss: 0.8892
# Epoch 102/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7510 - box_loss: 0.6207 - class_loss: 0.1302 - val_loss: 3.0119 - val_box_loss: 2.0291 - val_class_loss: 0.9827
# Epoch 103/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.7480 - box_loss: 0.6190 - class_loss: 0.1290 - val_loss: 2.8603 - val_box_loss: 2.0460 - val_class_loss: 0.8143
# Epoch 104/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7467 - box_loss: 0.6191 - class_loss: 0.1276 - val_loss: 2.9142 - val_box_loss: 2.0562 - val_class_loss: 0.8580
# Epoch 105/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.7394 - box_loss: 0.6129 - class_loss: 0.1265 - val_loss: 3.0101 - val_box_loss: 2.0916 - val_class_loss: 0.9185
# Epoch 106/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.7370 - box_loss: 0.6110 - class_loss: 0.1260 - val_loss: 3.0044 - val_box_loss: 2.1052 - val_class_loss: 0.8992
# Epoch 107/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7424 - box_loss: 0.6142 - class_loss: 0.1282 - val_loss: 2.9154 - val_box_loss: 1.9964 - val_class_loss: 0.9190
# Epoch 108/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.7287 - box_loss: 0.6028 - class_loss: 0.1259 - val_loss: 2.9045 - val_box_loss: 2.1190 - val_class_loss: 0.7855
# Epoch 109/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7323 - box_loss: 0.6088 - class_loss: 0.1235 - val_loss: 2.9820 - val_box_loss: 2.0970 - val_class_loss: 0.8849
# Epoch 110/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7367 - box_loss: 0.6103 - class_loss: 0.1264 - val_loss: 2.9611 - val_box_loss: 2.0752 - val_class_loss: 0.8859
# Epoch 111/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7297 - box_loss: 0.6035 - class_loss: 0.1262 - val_loss: 2.9067 - val_box_loss: 2.0247 - val_class_loss: 0.8820
# Epoch 112/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7158 - box_loss: 0.5954 - class_loss: 0.1204 - val_loss: 2.9216 - val_box_loss: 2.0679 - val_class_loss: 0.8537
# Epoch 113/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.7220 - box_loss: 0.5957 - class_loss: 0.1263 - val_loss: 2.9232 - val_box_loss: 2.1006 - val_class_loss: 0.8226
# Epoch 114/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.6961 - box_loss: 0.5742 - class_loss: 0.1219 - val_loss: 2.8808 - val_box_loss: 2.0055 - val_class_loss: 0.8753
# Epoch 115/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7209 - box_loss: 0.5996 - class_loss: 0.1213 - val_loss: 2.9263 - val_box_loss: 1.9791 - val_class_loss: 0.9472
# Epoch 116/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.7033 - box_loss: 0.5829 - class_loss: 0.1204 - val_loss: 2.9620 - val_box_loss: 1.9963 - val_class_loss: 0.9657
# Epoch 117/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7072 - box_loss: 0.5852 - class_loss: 0.1220 - val_loss: 2.9952 - val_box_loss: 2.1259 - val_class_loss: 0.8692
# Epoch 118/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7101 - box_loss: 0.5878 - class_loss: 0.1223 - val_loss: 2.9379 - val_box_loss: 2.0064 - val_class_loss: 0.9315
# Epoch 119/120
# 536/536 [==============================] - 46s 86ms/step - loss: 0.7092 - box_loss: 0.5887 - class_loss: 0.1205 - val_loss: 2.9473 - val_box_loss: 2.0562 - val_class_loss: 0.8911
# Epoch 120/120
# 536/536 [==============================] - 46s 85ms/step - loss: 0.7177 - box_loss: 0.5951 - class_loss: 0.1226 - val_loss: 2.9292 - val_box_loss: 2.0939 - val_class_loss: 0.8353

# %% [markdown]
# # <span style="color:#e74c3c;"> Training </span> Results, Evaluation

# %%
fig, axs = plt.subplots(1,3, figsize = (18,5), dpi = 130)

axs[0].grid(linestyle="dashdot")
axs[0].set_title("Loss")
axs[0].plot(hist.history['loss'][1:])
axs[0].plot(hist.history['val_loss'][1:])
axs[0].legend(["train", "validataion"])

axs[1].grid(linestyle="dashdot")
axs[1].set_title("Box Loss")
axs[1].plot(hist.history['box_loss'])
axs[1].plot(hist.history['val_box_loss'])
axs[1].legend(["train",  "validataion"])

axs[2].grid(linestyle="dashdot")
axs[2].set_title("Class Loss")
axs[2].plot(hist.history['class_loss'][1:])
axs[2].plot(hist.history['val_class_loss'][1:])
axs[2].legend(["train",  "validataion"])

# %% [markdown]
# # <span style="color:#e74c3c;"> Test </span> Predictions

# %%
def visualize_predict_detections(model, dataset, bounding_box_format):
    images, y_true = next(iter(dataset.take(1)))
        
    y_pred = model.predict(images)
    y_pred = keras_cv.bounding_box.to_ragged(y_pred)
    
    keras_cv.visualization.plot_bounding_box_gallery(
        images,
        value_range=(0, 255),
        bounding_box_format=bounding_box_format,
        y_true=y_true,
        y_pred=y_pred,
        true_color = (192, 57, 43),
        pred_color=(255, 235, 59),
        scale = 8,
        font_scale = 0.8,
        line_thickness=2,
        dpi = 100,
        rows=2,
        cols=2,
        show=True,
        class_mapping=class_mapping,
    )

# %%
# red -> ground true
# yellow -> prediction

visualize_predict_detections(YOLOV8_model, dataset = test_dataset, bounding_box_format="xyxy")
# Out:
# 1/1 [==============================] - 4s 4s/step
